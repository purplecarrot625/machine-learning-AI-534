# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
import pandas as pd

# %%
num_processor = 'passthrough' # i.e., no transformation
cat_processor = OneHotEncoder(sparse=False, handle_unknown='ignore')

# %%
names = ["age", "sector", "education", "marital-status", "occupation", "race", "sex", "hours-per-week", "country-of-origin", "target"]

# %%
data = pd.read_csv("income.train.txt.5k", names = names)

# %%
#  includes transformations for all the categorical columns in the dataset
preprocessor = ColumnTransformer([
           ('num', num_processor, ['age', 'hours-per-week']),
           ('sector', cat_processor, ['sector']),
           ('education', cat_processor, ['education']),
           ('marital-status', cat_processor, ['marital-status']),
           ('occupation', cat_processor, ['occupation']),
           ('race', cat_processor, ['race']),
           ('sex', cat_processor, ['sex']),
           ('country', cat_processor, ['country-of-origin']),
       ])
preprocessor.fit(data)
processed_data = preprocessor.transform(data)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
processed_data
# Out:
# array([[50., 13.,  0., ...,  1.,  0.,  0.],
#        [38., 40.,  0., ...,  1.,  0.,  0.],
#        [53., 40.,  0., ...,  1.,  0.,  0.],
#        ...,
#        [61.,  5.,  0., ...,  1.,  0.,  0.],
#        [42., 40.,  0., ...,  1.,  0.,  0.],
#        [21., 40.,  0., ...,  1.,  0.,  0.]])

# %%
# After fitting the ColumnTransformer to the data, 
# We can retrieve the feature names using the get_feature_names_out() method
feature_names = preprocessor.get_feature_names_out()
feature_names
# Out:
# array(['num__age', 'num__hours-per-week', 'sector__sector_ Federal-gov',
#        'sector__sector_ Local-gov', 'sector__sector_ Private',
#        'sector__sector_ Self-emp-inc', 'sector__sector_ Self-emp-not-inc',
#        'sector__sector_ State-gov', 'sector__sector_ Without-pay',
#        'education__education_ 10th', 'education__education_ 11th',
#        'education__education_ 12th', 'education__education_ 1st-4th',
#        'education__education_ 5th-6th', 'education__education_ 7th-8th',
#        'education__education_ 9th', 'education__education_ Assoc-acdm',
#        'education__education_ Assoc-voc',
#        'education__education_ Bachelors',
#        'education__education_ Doctorate', 'education__education_ HS-grad',
#        'education__education_ Masters', 'education__education_ Preschool',
#        'education__education_ Prof-school',
#        'education__education_ Some-college',
#        'marital-status__marital-status_ Divorced',
#        'marital-status__marital-status_ Married-AF-spouse',
#        'marital-status__marital-status_ Married-civ-spouse',
#        'marital-status__marital-status_ Married-spouse-absent',
#        'marital-status__marital-status_ Never-married',
#        'marital-status__marital-status_ Separated',
#        'marital-status__marital-status_ Widowed',
#        'occupation__occupation_ Adm-clerical',
#        'occupation__occupation_ Armed-Forces',
#        'occupation__occupation_ Craft-repair',
#        'occupation__occupation_ Exec-managerial',
#        'occupation__occupation_ Farming-fishing',
#        'occupation__occupation_ Handlers-cleaners',
#        'occupation__occupation_ Machine-op-inspct',
#        'occupation__occupation_ Other-service',
#        'occupation__occupation_ Priv-house-serv',
#        'occupation__occupation_ Prof-specialty',
#        'occupation__occupation_ Protective-serv',
#        'occupation__occupation_ Sales',
#        'occupation__occupation_ Tech-support',
#        'occupation__occupation_ Transport-moving',
#        'race__race_ Amer-Indian-Eskimo', 'race__race_ Asian-Pac-Islander',
#        'race__race_ Black', 'race__race_ Other', 'race__race_ White',
#        'sex__sex_ Female', 'sex__sex_ Male',
#        'country__country-of-origin_ Cambodia',
#        'country__country-of-origin_ Canada',
#        'country__country-of-origin_ China',
#        'country__country-of-origin_ Columbia',
#        'country__country-of-origin_ Cuba',
#        'country__country-of-origin_ Dominican-Republic',
#        'country__country-of-origin_ Ecuador',
#        'country__country-of-origin_ El-Salvador',
#        'country__country-of-origin_ England',
#        'country__country-of-origin_ France',
#        'country__country-of-origin_ Germany',
#        'country__country-of-origin_ Greece',
#        'country__country-of-origin_ Guatemala',
#        'country__country-of-origin_ Haiti',
#        'country__country-of-origin_ Honduras',
#        'country__country-of-origin_ Hong',
#        'country__country-of-origin_ India',
#        'country__country-of-origin_ Iran',
#        'country__country-of-origin_ Ireland',
#        'country__country-of-origin_ Italy',
#        'country__country-of-origin_ Jamaica',
#        'country__country-of-origin_ Japan',
#        'country__country-of-origin_ Laos',
#        'country__country-of-origin_ Mexico',
#        'country__country-of-origin_ Nicaragua',
#        'country__country-of-origin_ Outlying-US(Guam-USVI-etc)',
#        'country__country-of-origin_ Peru',
#        'country__country-of-origin_ Philippines',
#        'country__country-of-origin_ Poland',
#        'country__country-of-origin_ Portugal',
#        'country__country-of-origin_ Puerto-Rico',
#        'country__country-of-origin_ Scotland',
#        'country__country-of-origin_ South',
#        'country__country-of-origin_ Taiwan',
#        'country__country-of-origin_ Thailand',
#        'country__country-of-origin_ Trinadad&Tobago',
#        'country__country-of-origin_ United-States',
#        'country__country-of-origin_ Vietnam',
#        'country__country-of-origin_ Yugoslavia'], dtype=object)

# %%
count = len(feature_names)
count
# Out:
# 92

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
dev_data = pd.read_csv("income.dev.txt", names = names)

# %%
processed_dev_data = preprocessor.transform(dev_data)
X_dev = processed_dev_data
y_dev = (dev_data["target"].str.strip() == '>50K').astype(int).values  # Convert target to binary (assuming '>50K' is the positive class)

# %%
X_train = processed_data
y_train = (data["target"].str.strip() == '>50K').astype(int).values

# %%
training_error_rates = []
dev_error_rates = []
training_positive_rates = []
dev_positive_rates = []

# %%
y_train[-4]
# Out:
# 1

# %%
for k in range(1, 101, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    
    train_preds = knn.predict(X_train)
    dev_preds = knn.predict(X_dev)
    
    train_error_rate = 1 - accuracy_score(y_train, train_preds)
    dev_error_rate = 1 - accuracy_score(y_dev, dev_preds)
    
    training_error_rates.append(train_error_rate)
    dev_error_rates.append(dev_error_rate)
    
    print(f"k={k}: Training Error Rate = {train_error_rate:.4f}, Dev Error Rate = {dev_error_rate:.4f}")
# Out:
# k=1: Training Error Rate = 0.0152, Dev Error Rate = 0.2690
# k=3: Training Error Rate = 0.1300, Dev Error Rate = 0.2400
# k=5: Training Error Rate = 0.1562, Dev Error Rate = 0.2340
# k=7: Training Error Rate = 0.1684, Dev Error Rate = 0.2330
# k=9: Training Error Rate = 0.1828, Dev Error Rate = 0.2220
# k=11: Training Error Rate = 0.1882, Dev Error Rate = 0.2190
# k=13: Training Error Rate = 0.1898, Dev Error Rate = 0.2170
# k=15: Training Error Rate = 0.1924, Dev Error Rate = 0.2150
# k=17: Training Error Rate = 0.1948, Dev Error Rate = 0.2210
# k=19: Training Error Rate = 0.1966, Dev Error Rate = 0.2140
# k=21: Training Error Rate = 0.1978, Dev Error Rate = 0.2170
# k=23: Training Error Rate = 0.2028, Dev Error Rate = 0.2230
# k=25: Training Error Rate = 0.2010, Dev Error Rate = 0.2210
# k=27: Training Error Rate = 0.2078, Dev Error Rate = 0.2200
# k=29: Training Error Rate = 0.2146, Dev Error Rate = 0.2130
# k=31: Training Error Rate = 0.2094, Dev Error Rate = 0.2140
# k=33: Training Error Rate = 0.2136, Dev Error Rate = 0.2070
# k=35: Training Error Rate = 0.2140, Dev Error Rate = 0.2130
# k=37: Training Error Rate = 0.2140, Dev Error Rate = 0.2170
# k=39: Training Error Rate = 0.2168, Dev Error Rate = 0.2180
# k=41: Training Error Rate = 0.2172, Dev Error Rate = 0.2180
# k=43: Training Error Rate = 0.2156, Dev Error Rate = 0.2230
# k=45: Training Error Rate = 0.2194, Dev Error Rate = 0.2230
# k=47: Training Error Rate = 0.2186, Dev Error Rate = 0.2270
# k=49: Training Error Rate = 0.2214, Dev Error Rate = 0.2200
# k=51: Training Error Rate = 0.2228, Dev Error Rate = 0.2210
# k=53: Training Error Rate = 0.2256, Dev Error Rate = 0.2240
# k=55: Training Error Rate = 0.2278, Dev Error Rate = 0.2230
# k=57: Training Error Rate = 0.2280, Dev Error Rate = 0.2180
# k=59: Training Error Rate = 0.2278, Dev Error Rate = 0.2190
# k=61: Training Error Rate = 0.2298, Dev Error Rate = 0.2240
# k=63: Training Error Rate = 0.2282, Dev Error Rate = 0.2270
# k=65: Training Error Rate = 0.2294, Dev Error Rate = 0.2260
# k=67: Training Error Rate = 0.2306, Dev Error Rate = 0.2220
# k=69: Training Error Rate = 0.2308, Dev Error Rate = 0.2220
# k=71: Training Error Rate = 0.2304, Dev Error Rate = 0.2290
# k=73: Training Error Rate = 0.2294, Dev Error Rate = 0.2210
# k=75: Training Error Rate = 0.2310, Dev Error Rate = 0.2250
# k=77: Training Error Rate = 0.2300, Dev Error Rate = 0.2200
# k=79: Training Error Rate = 0.2332, Dev Error Rate = 0.2230
# k=81: Training Error Rate = 0.2324, Dev Error Rate = 0.2190
# k=83: Training Error Rate = 0.2302, Dev Error Rate = 0.2240
# k=85: Training Error Rate = 0.2336, Dev Error Rate = 0.2190
# k=87: Training Error Rate = 0.2364, Dev Error Rate = 0.2220
# k=89: Training Error Rate = 0.2352, Dev Error Rate = 0.2260
# k=91: Training Error Rate = 0.2332, Dev Error Rate = 0.2250
# k=93: Training Error Rate = 0.2356, Dev Error Rate = 0.2280
# k=95: Training Error Rate = 0.2326, Dev Error Rate = 0.2240
# k=97: Training Error Rate = 0.2332, Dev Error Rate = 0.2250
# k=99: Training Error Rate = 0.2310, Dev Error Rate = 0.2310

# %%
# Question - 2
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
num_processor = MinMaxScaler(feature_range=(0, 2))
cat_processor = OneHotEncoder(sparse=False, handle_unknown='ignore')

# %%
preprocessor = ColumnTransformer([
           ('num', num_processor, ['age', 'hours-per-week']),
           ('sector', cat_processor, ['sector']),
           ('education', cat_processor, ['education']),
           ('marital-status', cat_processor, ['marital-status']),
           ('occupation', cat_processor, ['occupation']),
           ('race', cat_processor, ['race']),
           ('sex', cat_processor, ['sex']),
           ('country', cat_processor, ['country-of-origin']),
       ])
preprocessor.fit(data)
processed_data = preprocessor.transform(data)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /opt/homebrew/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_train = processed_data
y_train = (data["target"].str.strip() == '>50K').astype(int).values

# %%
processed_dev_data = preprocessor.transform(dev_data)
X_dev = processed_dev_data
y_dev = (dev_data["target"].str.strip() == '>50K').astype(int).values
training_error_rates = []
dev_error_rates = []
training_positive_rates = []
dev_positive_rates = []
for k in range(1, 1001, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    
    train_preds = knn.predict(X_train)
    dev_preds = knn.predict(X_dev)
    
    train_error_rate = 1 - accuracy_score(y_train, train_preds)
    dev_error_rate = 1 - accuracy_score(y_dev, dev_preds)
    
    training_error_rates.append(train_error_rate)
    dev_error_rates.append(dev_error_rate)
    
    print(f"k={k}: Training Error Rate = {train_error_rate:.4f}, Dev Error Rate = {dev_error_rate:.4f}")
# Out:
# k=1: Training Error Rate = 0.0152, Dev Error Rate = 0.2370
# k=3: Training Error Rate = 0.1152, Dev Error Rate = 0.1920
# k=5: Training Error Rate = 0.1376, Dev Error Rate = 0.1830
# k=7: Training Error Rate = 0.1410, Dev Error Rate = 0.1680
# k=9: Training Error Rate = 0.1552, Dev Error Rate = 0.1590
# k=11: Training Error Rate = 0.1634, Dev Error Rate = 0.1630
# k=13: Training Error Rate = 0.1634, Dev Error Rate = 0.1640
# k=15: Training Error Rate = 0.1642, Dev Error Rate = 0.1570
# k=17: Training Error Rate = 0.1660, Dev Error Rate = 0.1610
# k=19: Training Error Rate = 0.1690, Dev Error Rate = 0.1640
# k=21: Training Error Rate = 0.1702, Dev Error Rate = 0.1590
# k=23: Training Error Rate = 0.1708, Dev Error Rate = 0.1540
# k=25: Training Error Rate = 0.1696, Dev Error Rate = 0.1500
# k=27: Training Error Rate = 0.1692, Dev Error Rate = 0.1560
# k=29: Training Error Rate = 0.1700, Dev Error Rate = 0.1520
# k=31: Training Error Rate = 0.1706, Dev Error Rate = 0.1520
# k=33: Training Error Rate = 0.1712, Dev Error Rate = 0.1550
# k=35: Training Error Rate = 0.1722, Dev Error Rate = 0.1500
# k=37: Training Error Rate = 0.1720, Dev Error Rate = 0.1480
# k=39: Training Error Rate = 0.1726, Dev Error Rate = 0.1470
# k=41: Training Error Rate = 0.1744, Dev Error Rate = 0.1430
# k=43: Training Error Rate = 0.1740, Dev Error Rate = 0.1490
# k=45: Training Error Rate = 0.1760, Dev Error Rate = 0.1500
# k=47: Training Error Rate = 0.1786, Dev Error Rate = 0.1530
# k=49: Training Error Rate = 0.1800, Dev Error Rate = 0.1510
# k=51: Training Error Rate = 0.1802, Dev Error Rate = 0.1550
# k=53: Training Error Rate = 0.1798, Dev Error Rate = 0.1540
# k=55: Training Error Rate = 0.1796, Dev Error Rate = 0.1540
# k=57: Training Error Rate = 0.1808, Dev Error Rate = 0.1560
# k=59: Training Error Rate = 0.1810, Dev Error Rate = 0.1520
# k=61: Training Error Rate = 0.1794, Dev Error Rate = 0.1570
# k=63: Training Error Rate = 0.1806, Dev Error Rate = 0.1540
# k=65: Training Error Rate = 0.1782, Dev Error Rate = 0.1540
# k=67: Training Error Rate = 0.1778, Dev Error Rate = 0.1530
# k=69: Training Error Rate = 0.1790, Dev Error Rate = 0.1510
# k=71: Training Error Rate = 0.1786, Dev Error Rate = 0.1530
# k=73: Training Error Rate = 0.1780, Dev Error Rate = 0.1490
# k=75: Training Error Rate = 0.1784, Dev Error Rate = 0.1480
# k=77: Training Error Rate = 0.1788, Dev Error Rate = 0.1490
# k=79: Training Error Rate = 0.1786, Dev Error Rate = 0.1510
# k=81: Training Error Rate = 0.1774, Dev Error Rate = 0.1510
# k=83: Training Error Rate = 0.1772, Dev Error Rate = 0.1540
# k=85: Training Error Rate = 0.1770, Dev Error Rate = 0.1530
# k=87: Training Error Rate = 0.1776, Dev Error Rate = 0.1550
# k=89: Training Error Rate = 0.1788, Dev Error Rate = 0.1520
# k=91: Training Error Rate = 0.1788, Dev Error Rate = 0.1540
# k=93: Training Error Rate = 0.1792, Dev Error Rate = 0.1520
# k=95: Training Error Rate = 0.1778, Dev Error Rate = 0.1540
# k=97: Training Error Rate = 0.1786, Dev Error Rate = 0.1570
# k=99: Training Error Rate = 0.1780, Dev Error Rate = 0.1580
# k=101: Training Error Rate = 0.1776, Dev Error Rate = 0.1590
# k=103: Training Error Rate = 0.1788, Dev Error Rate = 0.1590
# k=105: Training Error Rate = 0.1790, Dev Error Rate = 0.1590
# k=107: Training Error Rate = 0.1786, Dev Error Rate = 0.1580
# k=109: Training Error Rate = 0.1780, Dev Error Rate = 0.1600
# k=111: Training Error Rate = 0.1794, Dev Error Rate = 0.1570
# k=113: Training Error Rate = 0.1798, Dev Error Rate = 0.1580
# k=115: Training Error Rate = 0.1794, Dev Error Rate = 0.1600
# k=117: Training Error Rate = 0.1804, Dev Error Rate = 0.1560
# k=119: Training Error Rate = 0.1798, Dev Error Rate = 0.1590
# k=121: Training Error Rate = 0.1798, Dev Error Rate = 0.1600
# k=123: Training Error Rate = 0.1802, Dev Error Rate = 0.1560
# k=125: Training Error Rate = 0.1798, Dev Error Rate = 0.1590
# k=127: Training Error Rate = 0.1806, Dev Error Rate = 0.1550
# k=129: Training Error Rate = 0.1806, Dev Error Rate = 0.1570
# k=131: Training Error Rate = 0.1802, Dev Error Rate = 0.1500
# k=133: Training Error Rate = 0.1810, Dev Error Rate = 0.1510
# k=135: Training Error Rate = 0.1810, Dev Error Rate = 0.1500
# k=137: Training Error Rate = 0.1806, Dev Error Rate = 0.1520
# k=139: Training Error Rate = 0.1810, Dev Error Rate = 0.1540
# k=141: Training Error Rate = 0.1806, Dev Error Rate = 0.1520
# k=143: Training Error Rate = 0.1800, Dev Error Rate = 0.1510
# k=145: Training Error Rate = 0.1798, Dev Error Rate = 0.1510
# k=147: Training Error Rate = 0.1796, Dev Error Rate = 0.1510
# k=149: Training Error Rate = 0.1788, Dev Error Rate = 0.1530
# k=151: Training Error Rate = 0.1796, Dev Error Rate = 0.1540
# k=153: Training Error Rate = 0.1800, Dev Error Rate = 0.1530
# k=155: Training Error Rate = 0.1794, Dev Error Rate = 0.1530
# k=157: Training Error Rate = 0.1786, Dev Error Rate = 0.1550
# k=159: Training Error Rate = 0.1788, Dev Error Rate = 0.1550
# k=161: Training Error Rate = 0.1796, Dev Error Rate = 0.1540
# k=163: Training Error Rate = 0.1790, Dev Error Rate = 0.1550
# k=165: Training Error Rate = 0.1786, Dev Error Rate = 0.1550
# k=167: Training Error Rate = 0.1782, Dev Error Rate = 0.1560
# k=169: Training Error Rate = 0.1786, Dev Error Rate = 0.1570
# k=171: Training Error Rate = 0.1792, Dev Error Rate = 0.1540
# k=173: Training Error Rate = 0.1800, Dev Error Rate = 0.1540
# k=175: Training Error Rate = 0.1804, Dev Error Rate = 0.1560
# k=177: Training Error Rate = 0.1808, Dev Error Rate = 0.1570
# k=179: Training Error Rate = 0.1800, Dev Error Rate = 0.1540
# k=181: Training Error Rate = 0.1806, Dev Error Rate = 0.1550
# k=183: Training Error Rate = 0.1806, Dev Error Rate = 0.1590
# k=185: Training Error Rate = 0.1814, Dev Error Rate = 0.1570
# k=187: Training Error Rate = 0.1812, Dev Error Rate = 0.1570
# k=189: Training Error Rate = 0.1804, Dev Error Rate = 0.1580
# k=191: Training Error Rate = 0.1806, Dev Error Rate = 0.1600
# k=193: Training Error Rate = 0.1800, Dev Error Rate = 0.1590
# k=195: Training Error Rate = 0.1794, Dev Error Rate = 0.1580
# k=197: Training Error Rate = 0.1792, Dev Error Rate = 0.1570
# k=199: Training Error Rate = 0.1794, Dev Error Rate = 0.1580
# k=201: Training Error Rate = 0.1806, Dev Error Rate = 0.1590
# k=203: Training Error Rate = 0.1808, Dev Error Rate = 0.1570
# k=205: Training Error Rate = 0.1806, Dev Error Rate = 0.1590
# k=207: Training Error Rate = 0.1802, Dev Error Rate = 0.1570
# k=209: Training Error Rate = 0.1814, Dev Error Rate = 0.1560
# k=211: Training Error Rate = 0.1812, Dev Error Rate = 0.1580
# k=213: Training Error Rate = 0.1812, Dev Error Rate = 0.1590
# k=215: Training Error Rate = 0.1812, Dev Error Rate = 0.1580
# k=217: Training Error Rate = 0.1806, Dev Error Rate = 0.1590
# k=219: Training Error Rate = 0.1818, Dev Error Rate = 0.1590
# k=221: Training Error Rate = 0.1810, Dev Error Rate = 0.1570
# k=223: Training Error Rate = 0.1810, Dev Error Rate = 0.1580
# k=225: Training Error Rate = 0.1822, Dev Error Rate = 0.1600
# k=227: Training Error Rate = 0.1820, Dev Error Rate = 0.1570
# k=229: Training Error Rate = 0.1818, Dev Error Rate = 0.1580
# k=231: Training Error Rate = 0.1820, Dev Error Rate = 0.1570
# k=233: Training Error Rate = 0.1820, Dev Error Rate = 0.1570
# k=235: Training Error Rate = 0.1818, Dev Error Rate = 0.1570
# k=237: Training Error Rate = 0.1818, Dev Error Rate = 0.1570
# k=239: Training Error Rate = 0.1822, Dev Error Rate = 0.1570
# k=241: Training Error Rate = 0.1824, Dev Error Rate = 0.1570
# k=243: Training Error Rate = 0.1818, Dev Error Rate = 0.1570
# k=245: Training Error Rate = 0.1818, Dev Error Rate = 0.1570
# k=247: Training Error Rate = 0.1820, Dev Error Rate = 0.1570
# k=249: Training Error Rate = 0.1822, Dev Error Rate = 0.1570
# k=251: Training Error Rate = 0.1820, Dev Error Rate = 0.1580
# k=253: Training Error Rate = 0.1822, Dev Error Rate = 0.1580
# k=255: Training Error Rate = 0.1820, Dev Error Rate = 0.1580
# k=257: Training Error Rate = 0.1824, Dev Error Rate = 0.1580
# k=259: Training Error Rate = 0.1822, Dev Error Rate = 0.1590
# k=261: Training Error Rate = 0.1822, Dev Error Rate = 0.1590
# k=263: Training Error Rate = 0.1832, Dev Error Rate = 0.1590
# k=265: Training Error Rate = 0.1820, Dev Error Rate = 0.1590
# k=267: Training Error Rate = 0.1826, Dev Error Rate = 0.1590
# k=269: Training Error Rate = 0.1818, Dev Error Rate = 0.1600
# k=271: Training Error Rate = 0.1818, Dev Error Rate = 0.1610
# k=273: Training Error Rate = 0.1820, Dev Error Rate = 0.1610
# k=275: Training Error Rate = 0.1824, Dev Error Rate = 0.1610
# k=277: Training Error Rate = 0.1822, Dev Error Rate = 0.1600
# k=279: Training Error Rate = 0.1822, Dev Error Rate = 0.1610
# k=281: Training Error Rate = 0.1824, Dev Error Rate = 0.1600
# k=283: Training Error Rate = 0.1820, Dev Error Rate = 0.1600
# k=285: Training Error Rate = 0.1826, Dev Error Rate = 0.1600
# k=287: Training Error Rate = 0.1834, Dev Error Rate = 0.1610
# k=289: Training Error Rate = 0.1832, Dev Error Rate = 0.1610
# k=291: Training Error Rate = 0.1832, Dev Error Rate = 0.1590
# k=293: Training Error Rate = 0.1826, Dev Error Rate = 0.1610
# k=295: Training Error Rate = 0.1818, Dev Error Rate = 0.1590
# k=297: Training Error Rate = 0.1824, Dev Error Rate = 0.1610
# k=299: Training Error Rate = 0.1822, Dev Error Rate = 0.1610
# k=301: Training Error Rate = 0.1828, Dev Error Rate = 0.1600
# k=303: Training Error Rate = 0.1836, Dev Error Rate = 0.1590
# k=305: Training Error Rate = 0.1830, Dev Error Rate = 0.1600
# k=307: Training Error Rate = 0.1834, Dev Error Rate = 0.1610
# k=309: Training Error Rate = 0.1838, Dev Error Rate = 0.1610
# k=311: Training Error Rate = 0.1844, Dev Error Rate = 0.1610
# k=313: Training Error Rate = 0.1838, Dev Error Rate = 0.1610
# k=315: Training Error Rate = 0.1832, Dev Error Rate = 0.1620
# k=317: Training Error Rate = 0.1844, Dev Error Rate = 0.1600
# k=319: Training Error Rate = 0.1834, Dev Error Rate = 0.1620
# k=321: Training Error Rate = 0.1840, Dev Error Rate = 0.1620
# k=323: Training Error Rate = 0.1838, Dev Error Rate = 0.1610
# k=325: Training Error Rate = 0.1834, Dev Error Rate = 0.1630
# k=327: Training Error Rate = 0.1842, Dev Error Rate = 0.1620
# k=329: Training Error Rate = 0.1834, Dev Error Rate = 0.1640
# k=331: Training Error Rate = 0.1832, Dev Error Rate = 0.1630
# k=333: Training Error Rate = 0.1830, Dev Error Rate = 0.1650
# k=335: Training Error Rate = 0.1836, Dev Error Rate = 0.1630
# k=337: Training Error Rate = 0.1840, Dev Error Rate = 0.1640
# k=339: Training Error Rate = 0.1838, Dev Error Rate = 0.1650
# k=341: Training Error Rate = 0.1844, Dev Error Rate = 0.1630
# k=343: Training Error Rate = 0.1846, Dev Error Rate = 0.1640
# k=345: Training Error Rate = 0.1850, Dev Error Rate = 0.1630
# k=347: Training Error Rate = 0.1842, Dev Error Rate = 0.1620
# k=349: Training Error Rate = 0.1846, Dev Error Rate = 0.1640
# k=351: Training Error Rate = 0.1858, Dev Error Rate = 0.1630
# k=353: Training Error Rate = 0.1852, Dev Error Rate = 0.1640
# k=355: Training Error Rate = 0.1850, Dev Error Rate = 0.1620
# k=357: Training Error Rate = 0.1848, Dev Error Rate = 0.1630
# k=359: Training Error Rate = 0.1846, Dev Error Rate = 0.1610
# k=361: Training Error Rate = 0.1850, Dev Error Rate = 0.1630
# k=363: Training Error Rate = 0.1856, Dev Error Rate = 0.1630
# k=365: Training Error Rate = 0.1850, Dev Error Rate = 0.1620
# k=367: Training Error Rate = 0.1850, Dev Error Rate = 0.1640
# k=369: Training Error Rate = 0.1858, Dev Error Rate = 0.1630
# k=371: Training Error Rate = 0.1858, Dev Error Rate = 0.1640
# k=373: Training Error Rate = 0.1844, Dev Error Rate = 0.1630
# k=375: Training Error Rate = 0.1846, Dev Error Rate = 0.1640
# k=377: Training Error Rate = 0.1848, Dev Error Rate = 0.1660
# k=379: Training Error Rate = 0.1844, Dev Error Rate = 0.1650
# k=381: Training Error Rate = 0.1848, Dev Error Rate = 0.1660
# k=383: Training Error Rate = 0.1850, Dev Error Rate = 0.1640
# k=385: Training Error Rate = 0.1848, Dev Error Rate = 0.1640
# k=387: Training Error Rate = 0.1852, Dev Error Rate = 0.1650
# k=389: Training Error Rate = 0.1846, Dev Error Rate = 0.1630
# k=391: Training Error Rate = 0.1852, Dev Error Rate = 0.1640
# k=393: Training Error Rate = 0.1858, Dev Error Rate = 0.1640
# k=395: Training Error Rate = 0.1848, Dev Error Rate = 0.1640
# k=397: Training Error Rate = 0.1852, Dev Error Rate = 0.1650
# k=399: Training Error Rate = 0.1848, Dev Error Rate = 0.1650
# k=401: Training Error Rate = 0.1848, Dev Error Rate = 0.1650
# k=403: Training Error Rate = 0.1848, Dev Error Rate = 0.1640
# k=405: Training Error Rate = 0.1852, Dev Error Rate = 0.1650
# k=407: Training Error Rate = 0.1854, Dev Error Rate = 0.1650
# k=409: Training Error Rate = 0.1856, Dev Error Rate = 0.1650
# k=411: Training Error Rate = 0.1850, Dev Error Rate = 0.1650
# k=413: Training Error Rate = 0.1858, Dev Error Rate = 0.1650
# k=415: Training Error Rate = 0.1852, Dev Error Rate = 0.1650
# k=417: Training Error Rate = 0.1848, Dev Error Rate = 0.1660
# k=419: Training Error Rate = 0.1856, Dev Error Rate = 0.1650
# k=421: Training Error Rate = 0.1854, Dev Error Rate = 0.1650
# k=423: Training Error Rate = 0.1864, Dev Error Rate = 0.1650
# k=425: Training Error Rate = 0.1854, Dev Error Rate = 0.1650
# k=427: Training Error Rate = 0.1856, Dev Error Rate = 0.1650
# k=429: Training Error Rate = 0.1854, Dev Error Rate = 0.1650
# k=431: Training Error Rate = 0.1856, Dev Error Rate = 0.1650
# k=433: Training Error Rate = 0.1852, Dev Error Rate = 0.1640
# k=435: Training Error Rate = 0.1858, Dev Error Rate = 0.1640
# k=437: Training Error Rate = 0.1858, Dev Error Rate = 0.1640
# k=439: Training Error Rate = 0.1856, Dev Error Rate = 0.1660
# k=441: Training Error Rate = 0.1862, Dev Error Rate = 0.1660
# k=443: Training Error Rate = 0.1854, Dev Error Rate = 0.1680
# k=445: Training Error Rate = 0.1850, Dev Error Rate = 0.1680
# k=447: Training Error Rate = 0.1854, Dev Error Rate = 0.1690
# k=449: Training Error Rate = 0.1850, Dev Error Rate = 0.1700
# k=451: Training Error Rate = 0.1854, Dev Error Rate = 0.1700
# k=453: Training Error Rate = 0.1862, Dev Error Rate = 0.1680
# k=455: Training Error Rate = 0.1866, Dev Error Rate = 0.1700
# k=457: Training Error Rate = 0.1860, Dev Error Rate = 0.1700
# k=459: Training Error Rate = 0.1862, Dev Error Rate = 0.1690
# k=461: Training Error Rate = 0.1856, Dev Error Rate = 0.1680
# k=463: Training Error Rate = 0.1856, Dev Error Rate = 0.1690
# k=465: Training Error Rate = 0.1856, Dev Error Rate = 0.1670
# k=467: Training Error Rate = 0.1852, Dev Error Rate = 0.1670
# k=469: Training Error Rate = 0.1850, Dev Error Rate = 0.1670
# k=471: Training Error Rate = 0.1852, Dev Error Rate = 0.1680
# k=473: Training Error Rate = 0.1856, Dev Error Rate = 0.1680
# k=475: Training Error Rate = 0.1858, Dev Error Rate = 0.1680
# k=477: Training Error Rate = 0.1862, Dev Error Rate = 0.1680
# k=479: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=481: Training Error Rate = 0.1856, Dev Error Rate = 0.1660
# k=483: Training Error Rate = 0.1858, Dev Error Rate = 0.1660
# k=485: Training Error Rate = 0.1858, Dev Error Rate = 0.1670
# k=487: Training Error Rate = 0.1858, Dev Error Rate = 0.1670
# k=489: Training Error Rate = 0.1858, Dev Error Rate = 0.1670
# k=491: Training Error Rate = 0.1856, Dev Error Rate = 0.1660
# k=493: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=495: Training Error Rate = 0.1862, Dev Error Rate = 0.1650
# k=497: Training Error Rate = 0.1868, Dev Error Rate = 0.1650
# k=499: Training Error Rate = 0.1864, Dev Error Rate = 0.1640
# k=501: Training Error Rate = 0.1862, Dev Error Rate = 0.1660
# k=503: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=505: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=507: Training Error Rate = 0.1864, Dev Error Rate = 0.1660
# k=509: Training Error Rate = 0.1854, Dev Error Rate = 0.1660
# k=511: Training Error Rate = 0.1856, Dev Error Rate = 0.1660
# k=513: Training Error Rate = 0.1856, Dev Error Rate = 0.1650
# k=515: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=517: Training Error Rate = 0.1858, Dev Error Rate = 0.1650
# k=519: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=521: Training Error Rate = 0.1852, Dev Error Rate = 0.1650
# k=523: Training Error Rate = 0.1848, Dev Error Rate = 0.1650
# k=525: Training Error Rate = 0.1854, Dev Error Rate = 0.1660
# k=527: Training Error Rate = 0.1860, Dev Error Rate = 0.1660
# k=529: Training Error Rate = 0.1860, Dev Error Rate = 0.1630
# k=531: Training Error Rate = 0.1868, Dev Error Rate = 0.1640
# k=533: Training Error Rate = 0.1864, Dev Error Rate = 0.1680
# k=535: Training Error Rate = 0.1872, Dev Error Rate = 0.1690
# k=537: Training Error Rate = 0.1864, Dev Error Rate = 0.1690
# k=539: Training Error Rate = 0.1872, Dev Error Rate = 0.1690
# k=541: Training Error Rate = 0.1874, Dev Error Rate = 0.1690
# k=543: Training Error Rate = 0.1864, Dev Error Rate = 0.1680
# k=545: Training Error Rate = 0.1868, Dev Error Rate = 0.1680
# k=547: Training Error Rate = 0.1864, Dev Error Rate = 0.1700
# k=549: Training Error Rate = 0.1868, Dev Error Rate = 0.1710
# k=551: Training Error Rate = 0.1868, Dev Error Rate = 0.1690
# k=553: Training Error Rate = 0.1868, Dev Error Rate = 0.1690
# k=555: Training Error Rate = 0.1864, Dev Error Rate = 0.1680
# k=557: Training Error Rate = 0.1866, Dev Error Rate = 0.1690
# k=559: Training Error Rate = 0.1868, Dev Error Rate = 0.1680
# k=561: Training Error Rate = 0.1870, Dev Error Rate = 0.1690
# k=563: Training Error Rate = 0.1870, Dev Error Rate = 0.1690
# k=565: Training Error Rate = 0.1886, Dev Error Rate = 0.1690
# k=567: Training Error Rate = 0.1870, Dev Error Rate = 0.1690
# k=569: Training Error Rate = 0.1874, Dev Error Rate = 0.1710
# k=571: Training Error Rate = 0.1882, Dev Error Rate = 0.1700
# k=573: Training Error Rate = 0.1882, Dev Error Rate = 0.1710
# k=575: Training Error Rate = 0.1890, Dev Error Rate = 0.1720
# k=577: Training Error Rate = 0.1898, Dev Error Rate = 0.1710
# k=579: Training Error Rate = 0.1892, Dev Error Rate = 0.1710
# k=581: Training Error Rate = 0.1892, Dev Error Rate = 0.1710
# k=583: Training Error Rate = 0.1894, Dev Error Rate = 0.1700
# k=585: Training Error Rate = 0.1894, Dev Error Rate = 0.1690
# k=587: Training Error Rate = 0.1896, Dev Error Rate = 0.1690
# k=589: Training Error Rate = 0.1898, Dev Error Rate = 0.1690
# k=591: Training Error Rate = 0.1896, Dev Error Rate = 0.1680
# k=593: Training Error Rate = 0.1892, Dev Error Rate = 0.1710
# k=595: Training Error Rate = 0.1892, Dev Error Rate = 0.1690
# k=597: Training Error Rate = 0.1892, Dev Error Rate = 0.1700
# k=599: Training Error Rate = 0.1888, Dev Error Rate = 0.1710
# k=601: Training Error Rate = 0.1888, Dev Error Rate = 0.1710
# k=603: Training Error Rate = 0.1890, Dev Error Rate = 0.1720
# k=605: Training Error Rate = 0.1888, Dev Error Rate = 0.1680
# k=607: Training Error Rate = 0.1888, Dev Error Rate = 0.1680
# k=609: Training Error Rate = 0.1890, Dev Error Rate = 0.1680
# k=611: Training Error Rate = 0.1894, Dev Error Rate = 0.1700
# k=613: Training Error Rate = 0.1890, Dev Error Rate = 0.1700
# k=615: Training Error Rate = 0.1896, Dev Error Rate = 0.1690
# k=617: Training Error Rate = 0.1892, Dev Error Rate = 0.1700
# k=619: Training Error Rate = 0.1890, Dev Error Rate = 0.1680
# k=621: Training Error Rate = 0.1888, Dev Error Rate = 0.1680
# k=623: Training Error Rate = 0.1894, Dev Error Rate = 0.1680
# k=625: Training Error Rate = 0.1890, Dev Error Rate = 0.1690
# k=627: Training Error Rate = 0.1888, Dev Error Rate = 0.1690
# k=629: Training Error Rate = 0.1888, Dev Error Rate = 0.1700
# k=631: Training Error Rate = 0.1890, Dev Error Rate = 0.1690
# k=633: Training Error Rate = 0.1888, Dev Error Rate = 0.1690
# k=635: Training Error Rate = 0.1892, Dev Error Rate = 0.1690
# k=637: Training Error Rate = 0.1896, Dev Error Rate = 0.1680
# k=639: Training Error Rate = 0.1900, Dev Error Rate = 0.1700
# k=641: Training Error Rate = 0.1898, Dev Error Rate = 0.1700
# k=643: Training Error Rate = 0.1894, Dev Error Rate = 0.1710
# k=645: Training Error Rate = 0.1896, Dev Error Rate = 0.1710
# k=647: Training Error Rate = 0.1894, Dev Error Rate = 0.1720
# k=649: Training Error Rate = 0.1894, Dev Error Rate = 0.1710
# k=651: Training Error Rate = 0.1900, Dev Error Rate = 0.1710
# k=653: Training Error Rate = 0.1896, Dev Error Rate = 0.1720
# k=655: Training Error Rate = 0.1896, Dev Error Rate = 0.1720
# k=657: Training Error Rate = 0.1892, Dev Error Rate = 0.1720
# k=659: Training Error Rate = 0.1892, Dev Error Rate = 0.1720
# k=661: Training Error Rate = 0.1890, Dev Error Rate = 0.1720
# k=663: Training Error Rate = 0.1886, Dev Error Rate = 0.1720
# k=665: Training Error Rate = 0.1896, Dev Error Rate = 0.1710
# k=667: Training Error Rate = 0.1890, Dev Error Rate = 0.1710
# k=669: Training Error Rate = 0.1892, Dev Error Rate = 0.1720
# k=671: Training Error Rate = 0.1894, Dev Error Rate = 0.1720
# k=673: Training Error Rate = 0.1896, Dev Error Rate = 0.1710
# k=675: Training Error Rate = 0.1898, Dev Error Rate = 0.1700
# k=677: Training Error Rate = 0.1894, Dev Error Rate = 0.1690
# k=679: Training Error Rate = 0.1896, Dev Error Rate = 0.1700
# k=681: Training Error Rate = 0.1890, Dev Error Rate = 0.1700
# k=683: Training Error Rate = 0.1894, Dev Error Rate = 0.1690
# k=685: Training Error Rate = 0.1898, Dev Error Rate = 0.1690
# k=687: Training Error Rate = 0.1900, Dev Error Rate = 0.1700
# k=689: Training Error Rate = 0.1904, Dev Error Rate = 0.1690
# k=691: Training Error Rate = 0.1904, Dev Error Rate = 0.1700
# k=693: Training Error Rate = 0.1906, Dev Error Rate = 0.1700
# k=695: Training Error Rate = 0.1902, Dev Error Rate = 0.1700
# k=697: Training Error Rate = 0.1900, Dev Error Rate = 0.1700
# k=699: Training Error Rate = 0.1898, Dev Error Rate = 0.1710
# k=701: Training Error Rate = 0.1898, Dev Error Rate = 0.1700
# k=703: Training Error Rate = 0.1892, Dev Error Rate = 0.1710
# k=705: Training Error Rate = 0.1894, Dev Error Rate = 0.1700
# k=707: Training Error Rate = 0.1898, Dev Error Rate = 0.1690
# k=709: Training Error Rate = 0.1902, Dev Error Rate = 0.1690
# k=711: Training Error Rate = 0.1906, Dev Error Rate = 0.1690
# k=713: Training Error Rate = 0.1898, Dev Error Rate = 0.1690
# k=715: Training Error Rate = 0.1906, Dev Error Rate = 0.1690
# k=717: Training Error Rate = 0.1908, Dev Error Rate = 0.1690
# k=719: Training Error Rate = 0.1906, Dev Error Rate = 0.1710
# k=721: Training Error Rate = 0.1914, Dev Error Rate = 0.1710
# k=723: Training Error Rate = 0.1902, Dev Error Rate = 0.1690
# k=725: Training Error Rate = 0.1912, Dev Error Rate = 0.1710
# k=727: Training Error Rate = 0.1902, Dev Error Rate = 0.1710
# k=729: Training Error Rate = 0.1896, Dev Error Rate = 0.1710
# k=731: Training Error Rate = 0.1912, Dev Error Rate = 0.1710
# k=733: Training Error Rate = 0.1910, Dev Error Rate = 0.1710
# k=735: Training Error Rate = 0.1902, Dev Error Rate = 0.1710
# k=737: Training Error Rate = 0.1918, Dev Error Rate = 0.1730
# k=739: Training Error Rate = 0.1918, Dev Error Rate = 0.1730
# k=741: Training Error Rate = 0.1924, Dev Error Rate = 0.1740
# k=743: Training Error Rate = 0.1926, Dev Error Rate = 0.1730
# k=745: Training Error Rate = 0.1920, Dev Error Rate = 0.1730
# k=747: Training Error Rate = 0.1928, Dev Error Rate = 0.1730
# k=749: Training Error Rate = 0.1928, Dev Error Rate = 0.1730
# k=751: Training Error Rate = 0.1928, Dev Error Rate = 0.1730
# k=753: Training Error Rate = 0.1926, Dev Error Rate = 0.1740
# k=755: Training Error Rate = 0.1922, Dev Error Rate = 0.1740
# k=757: Training Error Rate = 0.1930, Dev Error Rate = 0.1750
# k=759: Training Error Rate = 0.1924, Dev Error Rate = 0.1740
# k=761: Training Error Rate = 0.1920, Dev Error Rate = 0.1740
# k=763: Training Error Rate = 0.1916, Dev Error Rate = 0.1740
# k=765: Training Error Rate = 0.1930, Dev Error Rate = 0.1730
# k=767: Training Error Rate = 0.1930, Dev Error Rate = 0.1730
# k=769: Training Error Rate = 0.1938, Dev Error Rate = 0.1740
# k=771: Training Error Rate = 0.1932, Dev Error Rate = 0.1750
# k=773: Training Error Rate = 0.1932, Dev Error Rate = 0.1750
# k=775: Training Error Rate = 0.1940, Dev Error Rate = 0.1750
# k=777: Training Error Rate = 0.1928, Dev Error Rate = 0.1770
# k=779: Training Error Rate = 0.1928, Dev Error Rate = 0.1770
# k=781: Training Error Rate = 0.1936, Dev Error Rate = 0.1750
# k=783: Training Error Rate = 0.1932, Dev Error Rate = 0.1750
# k=785: Training Error Rate = 0.1926, Dev Error Rate = 0.1760
# k=787: Training Error Rate = 0.1920, Dev Error Rate = 0.1750
# k=789: Training Error Rate = 0.1934, Dev Error Rate = 0.1760
# k=791: Training Error Rate = 0.1942, Dev Error Rate = 0.1770
# k=793: Training Error Rate = 0.1932, Dev Error Rate = 0.1770
# k=795: Training Error Rate = 0.1944, Dev Error Rate = 0.1770
# k=797: Training Error Rate = 0.1936, Dev Error Rate = 0.1780
# k=799: Training Error Rate = 0.1940, Dev Error Rate = 0.1780
# k=801: Training Error Rate = 0.1948, Dev Error Rate = 0.1790
# k=803: Training Error Rate = 0.1948, Dev Error Rate = 0.1780
# k=805: Training Error Rate = 0.1948, Dev Error Rate = 0.1760
# k=807: Training Error Rate = 0.1954, Dev Error Rate = 0.1790
# k=809: Training Error Rate = 0.1966, Dev Error Rate = 0.1780
# k=811: Training Error Rate = 0.1956, Dev Error Rate = 0.1780
# k=813: Training Error Rate = 0.1962, Dev Error Rate = 0.1780
# k=815: Training Error Rate = 0.1964, Dev Error Rate = 0.1780
# k=817: Training Error Rate = 0.1970, Dev Error Rate = 0.1770
# k=819: Training Error Rate = 0.1968, Dev Error Rate = 0.1780
# k=821: Training Error Rate = 0.1968, Dev Error Rate = 0.1780
# k=823: Training Error Rate = 0.1968, Dev Error Rate = 0.1790
# k=825: Training Error Rate = 0.1966, Dev Error Rate = 0.1790
# k=827: Training Error Rate = 0.1972, Dev Error Rate = 0.1790
# k=829: Training Error Rate = 0.1968, Dev Error Rate = 0.1790
# k=831: Training Error Rate = 0.1978, Dev Error Rate = 0.1810
# k=833: Training Error Rate = 0.1970, Dev Error Rate = 0.1820
# k=835: Training Error Rate = 0.1976, Dev Error Rate = 0.1810
# k=837: Training Error Rate = 0.1976, Dev Error Rate = 0.1810
# k=839: Training Error Rate = 0.1972, Dev Error Rate = 0.1810
# k=841: Training Error Rate = 0.1976, Dev Error Rate = 0.1840
# k=843: Training Error Rate = 0.1972, Dev Error Rate = 0.1830
# k=845: Training Error Rate = 0.1976, Dev Error Rate = 0.1810
# k=847: Training Error Rate = 0.1972, Dev Error Rate = 0.1810
# k=849: Training Error Rate = 0.1974, Dev Error Rate = 0.1820
# k=851: Training Error Rate = 0.1972, Dev Error Rate = 0.1840
# k=853: Training Error Rate = 0.1974, Dev Error Rate = 0.1820
# k=855: Training Error Rate = 0.1980, Dev Error Rate = 0.1830
# k=857: Training Error Rate = 0.1978, Dev Error Rate = 0.1800
# k=859: Training Error Rate = 0.1986, Dev Error Rate = 0.1800
# k=861: Training Error Rate = 0.1990, Dev Error Rate = 0.1820
# k=863: Training Error Rate = 0.1984, Dev Error Rate = 0.1820
# k=865: Training Error Rate = 0.1984, Dev Error Rate = 0.1790
# k=867: Training Error Rate = 0.1984, Dev Error Rate = 0.1840
# k=869: Training Error Rate = 0.1982, Dev Error Rate = 0.1820
# k=871: Training Error Rate = 0.1992, Dev Error Rate = 0.1810
# k=873: Training Error Rate = 0.2002, Dev Error Rate = 0.1810
# k=875: Training Error Rate = 0.2000, Dev Error Rate = 0.1810
# k=877: Training Error Rate = 0.2004, Dev Error Rate = 0.1810
# k=879: Training Error Rate = 0.1998, Dev Error Rate = 0.1800
# k=881: Training Error Rate = 0.2010, Dev Error Rate = 0.1810
# k=883: Training Error Rate = 0.2008, Dev Error Rate = 0.1810
# k=885: Training Error Rate = 0.2012, Dev Error Rate = 0.1800
# k=887: Training Error Rate = 0.2012, Dev Error Rate = 0.1810
# k=889: Training Error Rate = 0.2008, Dev Error Rate = 0.1800
# k=891: Training Error Rate = 0.2012, Dev Error Rate = 0.1810
# k=893: Training Error Rate = 0.2012, Dev Error Rate = 0.1800
# k=895: Training Error Rate = 0.2014, Dev Error Rate = 0.1820
# k=897: Training Error Rate = 0.2020, Dev Error Rate = 0.1820
# k=899: Training Error Rate = 0.2012, Dev Error Rate = 0.1820
# k=901: Training Error Rate = 0.2008, Dev Error Rate = 0.1820
# k=903: Training Error Rate = 0.2006, Dev Error Rate = 0.1820
# k=905: Training Error Rate = 0.2002, Dev Error Rate = 0.1810
# k=907: Training Error Rate = 0.2004, Dev Error Rate = 0.1820
# k=909: Training Error Rate = 0.2002, Dev Error Rate = 0.1820
# k=911: Training Error Rate = 0.2002, Dev Error Rate = 0.1820
# k=913: Training Error Rate = 0.1998, Dev Error Rate = 0.1820
# k=915: Training Error Rate = 0.2008, Dev Error Rate = 0.1840
# k=917: Training Error Rate = 0.2008, Dev Error Rate = 0.1830
# k=919: Training Error Rate = 0.2010, Dev Error Rate = 0.1820
# k=921: Training Error Rate = 0.2016, Dev Error Rate = 0.1820
# k=923: Training Error Rate = 0.2002, Dev Error Rate = 0.1820
# k=925: Training Error Rate = 0.2006, Dev Error Rate = 0.1820
# k=927: Training Error Rate = 0.2004, Dev Error Rate = 0.1830
# k=929: Training Error Rate = 0.2006, Dev Error Rate = 0.1820
# k=931: Training Error Rate = 0.2012, Dev Error Rate = 0.1820
# k=933: Training Error Rate = 0.1998, Dev Error Rate = 0.1820
# k=935: Training Error Rate = 0.2012, Dev Error Rate = 0.1830
# k=937: Training Error Rate = 0.2008, Dev Error Rate = 0.1820
# k=939: Training Error Rate = 0.2010, Dev Error Rate = 0.1820
# k=941: Training Error Rate = 0.2014, Dev Error Rate = 0.1810
# k=943: Training Error Rate = 0.2012, Dev Error Rate = 0.1810
# k=945: Training Error Rate = 0.2016, Dev Error Rate = 0.1800
# k=947: Training Error Rate = 0.2020, Dev Error Rate = 0.1800
# k=949: Training Error Rate = 0.2018, Dev Error Rate = 0.1810
# k=951: Training Error Rate = 0.2020, Dev Error Rate = 0.1820
# k=953: Training Error Rate = 0.2022, Dev Error Rate = 0.1820
# k=955: Training Error Rate = 0.2026, Dev Error Rate = 0.1820
# k=957: Training Error Rate = 0.2022, Dev Error Rate = 0.1820
# k=959: Training Error Rate = 0.2026, Dev Error Rate = 0.1820
# k=961: Training Error Rate = 0.2024, Dev Error Rate = 0.1800
# k=963: Training Error Rate = 0.2034, Dev Error Rate = 0.1820
# k=965: Training Error Rate = 0.2034, Dev Error Rate = 0.1820
# k=967: Training Error Rate = 0.2034, Dev Error Rate = 0.1830
# k=969: Training Error Rate = 0.2026, Dev Error Rate = 0.1820
# k=971: Training Error Rate = 0.2034, Dev Error Rate = 0.1820
# k=973: Training Error Rate = 0.2024, Dev Error Rate = 0.1820
# k=975: Training Error Rate = 0.2024, Dev Error Rate = 0.1810
# k=977: Training Error Rate = 0.2016, Dev Error Rate = 0.1800
# k=979: Training Error Rate = 0.2022, Dev Error Rate = 0.1790
# k=981: Training Error Rate = 0.2020, Dev Error Rate = 0.1800
# k=983: Training Error Rate = 0.2022, Dev Error Rate = 0.1810
# k=985: Training Error Rate = 0.2020, Dev Error Rate = 0.1780
# k=987: Training Error Rate = 0.2026, Dev Error Rate = 0.1800
# k=989: Training Error Rate = 0.2032, Dev Error Rate = 0.1790
# k=991: Training Error Rate = 0.2024, Dev Error Rate = 0.1780
# k=993: Training Error Rate = 0.2032, Dev Error Rate = 0.1780
# k=995: Training Error Rate = 0.2026, Dev Error Rate = 0.1790
# k=997: Training Error Rate = 0.2022, Dev Error Rate = 0.1770
# k=999: Training Error Rate = 0.2024, Dev Error Rate = 0.1790

# %%
# top-3 version
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Preprocessing
processed_dev_data = preprocessor.transform(dev_data)
X_dev = processed_dev_data
y_dev = (dev_data["target"].str.strip() == '>50K').astype(int).values

training_error_rates = []
dev_error_rates = []
training_positive_rates = []
dev_positive_rates = []

# Consider using a dictionary to store distances for easier organization
top_3_distances = {
    'euclidean': None,
    'manhattan': None
}

for metric in ['euclidean', 'manhattan']:
    for k in range(1, 101, 2):
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)
        knn.fit(X_train, y_train)
        
        train_preds = knn.predict(X_train)
        dev_preds = knn.predict(X_dev)
        
        train_error_rate = 1 - accuracy_score(y_train, train_preds)
        dev_error_rate = 1 - accuracy_score(y_dev, dev_preds)
        
        training_error_rates.append(train_error_rate)
        dev_error_rates.append(dev_error_rate)
        
        print(f"Metric={metric}, k={k}: Training Error Rate = {train_error_rate:.4f}, Dev Error Rate = {dev_error_rate:.4f}")
        
        # If k equals 3, get the distances for top-3 neighbors
        if k == 3:
            distances, _ = knn.kneighbors(X_dev, n_neighbors=3)
            top_3_distances[metric] = distances

# Accessing the distances:
euclidean_distances_top_3 = top_3_distances['euclidean']
manhattan_distances_top_3 = top_3_distances['manhattan']
# Out:
# Metric=euclidean, k=1: Training Error Rate = 0.0152, Dev Error Rate = 0.2370
# Metric=euclidean, k=3: Training Error Rate = 0.1152, Dev Error Rate = 0.1920
# Metric=euclidean, k=5: Training Error Rate = 0.1376, Dev Error Rate = 0.1830
# Metric=euclidean, k=7: Training Error Rate = 0.1410, Dev Error Rate = 0.1680
# Metric=euclidean, k=9: Training Error Rate = 0.1552, Dev Error Rate = 0.1590
# Metric=euclidean, k=11: Training Error Rate = 0.1634, Dev Error Rate = 0.1630
# Metric=euclidean, k=13: Training Error Rate = 0.1634, Dev Error Rate = 0.1640
# Metric=euclidean, k=15: Training Error Rate = 0.1642, Dev Error Rate = 0.1570
# Metric=euclidean, k=17: Training Error Rate = 0.1660, Dev Error Rate = 0.1610
# Metric=euclidean, k=19: Training Error Rate = 0.1690, Dev Error Rate = 0.1640
# Metric=euclidean, k=21: Training Error Rate = 0.1702, Dev Error Rate = 0.1590
# Metric=euclidean, k=23: Training Error Rate = 0.1708, Dev Error Rate = 0.1540
# Metric=euclidean, k=25: Training Error Rate = 0.1696, Dev Error Rate = 0.1500
# Metric=euclidean, k=27: Training Error Rate = 0.1692, Dev Error Rate = 0.1560
# Metric=euclidean, k=29: Training Error Rate = 0.1700, Dev Error Rate = 0.1520
# Metric=euclidean, k=31: Training Error Rate = 0.1706, Dev Error Rate = 0.1520
# Metric=euclidean, k=33: Training Error Rate = 0.1712, Dev Error Rate = 0.1550
# Metric=euclidean, k=35: Training Error Rate = 0.1722, Dev Error Rate = 0.1500
# Metric=euclidean, k=37: Training Error Rate = 0.1720, Dev Error Rate = 0.1480
# Metric=euclidean, k=39: Training Error Rate = 0.1726, Dev Error Rate = 0.1470
# Metric=euclidean, k=41: Training Error Rate = 0.1744, Dev Error Rate = 0.1430
# Metric=euclidean, k=43: Training Error Rate = 0.1740, Dev Error Rate = 0.1490
# Metric=euclidean, k=45: Training Error Rate = 0.1760, Dev Error Rate = 0.1500
# Metric=euclidean, k=47: Training Error Rate = 0.1786, Dev Error Rate = 0.1530
# Metric=euclidean, k=49: Training Error Rate = 0.1800, Dev Error Rate = 0.1510
# Metric=euclidean, k=51: Training Error Rate = 0.1802, Dev Error Rate = 0.1550
# Metric=euclidean, k=53: Training Error Rate = 0.1798, Dev Error Rate = 0.1540
# Metric=euclidean, k=55: Training Error Rate = 0.1796, Dev Error Rate = 0.1540
# Metric=euclidean, k=57: Training Error Rate = 0.1808, Dev Error Rate = 0.1560
# Metric=euclidean, k=59: Training Error Rate = 0.1810, Dev Error Rate = 0.1520
# Metric=euclidean, k=61: Training Error Rate = 0.1794, Dev Error Rate = 0.1570
# Metric=euclidean, k=63: Training Error Rate = 0.1806, Dev Error Rate = 0.1540
# Metric=euclidean, k=65: Training Error Rate = 0.1782, Dev Error Rate = 0.1540
# Metric=euclidean, k=67: Training Error Rate = 0.1778, Dev Error Rate = 0.1530
# Metric=euclidean, k=69: Training Error Rate = 0.1790, Dev Error Rate = 0.1510
# Metric=euclidean, k=71: Training Error Rate = 0.1786, Dev Error Rate = 0.1530
# Metric=euclidean, k=73: Training Error Rate = 0.1780, Dev Error Rate = 0.1490
# Metric=euclidean, k=75: Training Error Rate = 0.1784, Dev Error Rate = 0.1480
# Metric=euclidean, k=77: Training Error Rate = 0.1788, Dev Error Rate = 0.1490
# Metric=euclidean, k=79: Training Error Rate = 0.1786, Dev Error Rate = 0.1510
# Metric=euclidean, k=81: Training Error Rate = 0.1774, Dev Error Rate = 0.1510
# Metric=euclidean, k=83: Training Error Rate = 0.1772, Dev Error Rate = 0.1540
# Metric=euclidean, k=85: Training Error Rate = 0.1770, Dev Error Rate = 0.1530
# Metric=euclidean, k=87: Training Error Rate = 0.1776, Dev Error Rate = 0.1550
# Metric=euclidean, k=89: Training Error Rate = 0.1788, Dev Error Rate = 0.1520
# Metric=euclidean, k=91: Training Error Rate = 0.1788, Dev Error Rate = 0.1540
# Metric=euclidean, k=93: Training Error Rate = 0.1792, Dev Error Rate = 0.1520
# Metric=euclidean, k=95: Training Error Rate = 0.1778, Dev Error Rate = 0.1540
# Metric=euclidean, k=97: Training Error Rate = 0.1786, Dev Error Rate = 0.1570
# Metric=euclidean, k=99: Training Error Rate = 0.1780, Dev Error Rate = 0.1580
# Metric=manhattan, k=1: Training Error Rate = 0.0152, Dev Error Rate = 0.2400
# Metric=manhattan, k=3: Training Error Rate = 0.1168, Dev Error Rate = 0.1970
# Metric=manhattan, k=5: Training Error Rate = 0.1374, Dev Error Rate = 0.1770
# Metric=manhattan, k=7: Training Error Rate = 0.1456, Dev Error Rate = 0.1670
# Metric=manhattan, k=9: Training Error Rate = 0.1546, Dev Error Rate = 0.1610
# Metric=manhattan, k=11: Training Error Rate = 0.1642, Dev Error Rate = 0.1650
# Metric=manhattan, k=13: Training Error Rate = 0.1644, Dev Error Rate = 0.1650
# Metric=manhattan, k=15: Training Error Rate = 0.1686, Dev Error Rate = 0.1640
# Metric=manhattan, k=17: Training Error Rate = 0.1694, Dev Error Rate = 0.1550
# Metric=manhattan, k=19: Training Error Rate = 0.1692, Dev Error Rate = 0.1650
# Metric=manhattan, k=21: Training Error Rate = 0.1710, Dev Error Rate = 0.1640
# Metric=manhattan, k=23: Training Error Rate = 0.1704, Dev Error Rate = 0.1610
# Metric=manhattan, k=25: Training Error Rate = 0.1688, Dev Error Rate = 0.1550
# Metric=manhattan, k=27: Training Error Rate = 0.1686, Dev Error Rate = 0.1580
# Metric=manhattan, k=29: Training Error Rate = 0.1700, Dev Error Rate = 0.1550
# Metric=manhattan, k=31: Training Error Rate = 0.1708, Dev Error Rate = 0.1580
# Metric=manhattan, k=33: Training Error Rate = 0.1702, Dev Error Rate = 0.1560
# Metric=manhattan, k=35: Training Error Rate = 0.1694, Dev Error Rate = 0.1520
# Metric=manhattan, k=37: Training Error Rate = 0.1724, Dev Error Rate = 0.1480
# Metric=manhattan, k=39: Training Error Rate = 0.1724, Dev Error Rate = 0.1450
# Metric=manhattan, k=41: Training Error Rate = 0.1732, Dev Error Rate = 0.1420
# Metric=manhattan, k=43: Training Error Rate = 0.1750, Dev Error Rate = 0.1460
# Metric=manhattan, k=45: Training Error Rate = 0.1764, Dev Error Rate = 0.1470
# Metric=manhattan, k=47: Training Error Rate = 0.1772, Dev Error Rate = 0.1520
# Metric=manhattan, k=49: Training Error Rate = 0.1778, Dev Error Rate = 0.1510
# Metric=manhattan, k=51: Training Error Rate = 0.1774, Dev Error Rate = 0.1550
# Metric=manhattan, k=53: Training Error Rate = 0.1774, Dev Error Rate = 0.1520
# Metric=manhattan, k=55: Training Error Rate = 0.1796, Dev Error Rate = 0.1550
# Metric=manhattan, k=57: Training Error Rate = 0.1778, Dev Error Rate = 0.1510
# Metric=manhattan, k=59: Training Error Rate = 0.1792, Dev Error Rate = 0.1490
# Metric=manhattan, k=61: Training Error Rate = 0.1798, Dev Error Rate = 0.1480
# Metric=manhattan, k=63: Training Error Rate = 0.1798, Dev Error Rate = 0.1510
# Metric=manhattan, k=65: Training Error Rate = 0.1780, Dev Error Rate = 0.1530
# Metric=manhattan, k=67: Training Error Rate = 0.1784, Dev Error Rate = 0.1530
# Metric=manhattan, k=69: Training Error Rate = 0.1776, Dev Error Rate = 0.1510
# Metric=manhattan, k=71: Training Error Rate = 0.1762, Dev Error Rate = 0.1530
# Metric=manhattan, k=73: Training Error Rate = 0.1770, Dev Error Rate = 0.1500
# Metric=manhattan, k=75: Training Error Rate = 0.1770, Dev Error Rate = 0.1520
# Metric=manhattan, k=77: Training Error Rate = 0.1788, Dev Error Rate = 0.1530
# Metric=manhattan, k=79: Training Error Rate = 0.1796, Dev Error Rate = 0.1570
# Metric=manhattan, k=81: Training Error Rate = 0.1782, Dev Error Rate = 0.1560
# Metric=manhattan, k=83: Training Error Rate = 0.1784, Dev Error Rate = 0.1570
# Metric=manhattan, k=85: Training Error Rate = 0.1782, Dev Error Rate = 0.1520
# Metric=manhattan, k=87: Training Error Rate = 0.1778, Dev Error Rate = 0.1560
# Metric=manhattan, k=89: Training Error Rate = 0.1782, Dev Error Rate = 0.1530
# Metric=manhattan, k=91: Training Error Rate = 0.1788, Dev Error Rate = 0.1530
# Metric=manhattan, k=93: Training Error Rate = 0.1794, Dev Error Rate = 0.1550
# Metric=manhattan, k=95: Training Error Rate = 0.1786, Dev Error Rate = 0.1570
# Metric=manhattan, k=97: Training Error Rate = 0.1800, Dev Error Rate = 0.1520
# Metric=manhattan, k=99: Training Error Rate = 0.1788, Dev Error Rate = 0.1520

# %%
euclidean_distances_top_3
# Out:
# array([[0.33441929, 1.41527469, 1.41674697],
#        [2.48462326, 2.4886983 , 2.49291722],
#        [0.08219178, 0.16438356, 0.16554809],
#        ...,
#        [0.        , 0.02739726, 0.04915875],
#        [1.41894847, 1.43473041, 1.4625771 ],
#        [0.08219178, 0.21917808, 0.26530612]])

# %%
manhattan_distances_top_3
# Out:
# array([[0.38999161, 2.05479452, 2.10204082],
#        [6.49035505, 6.5649986 , 6.57254683],
#        [0.08219178, 0.16438356, 0.19066257],
#        ...,
#        [0.        , 0.02739726, 0.06821359],
#        [2.15683534, 2.3212189 , 2.41515236],
#        [0.08219178, 0.21917808, 0.26530612]])
